# %% [markdown]
# # Cours de Machine learning

# %% [markdown]
# ## Apprentissage supervisé - Regression lineaire

# %% [markdown]
# #### Exercice 1 : Prediction du prix d'une maison en fonction de sa surface

# %% [markdown]
# ### 1. Importation des bibliotheques

# %%
import pandas as pd # pour l'analyse de donneees
import matplotlib.pyplot as plt # pour la visualisation de donnnees
from sklearn import linear_model

# %% [markdown]
# ### 2. Chargement des donnees

# %%
df = pd.read_csv("prix_maisons.csv")

# %%
df
# Out:
#    Supervicie   Prix
# 0         200   8000
# 1         450  15000
# 2         150   1500
# 3          80    900
# 4          75   7500
# 5         320  74000
# 6         320  55000
# 7         450  11000
# 8         123    800
# 9          45    200

# %%
df.shape
# Out:
# (10, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Supervicie  10 non-null     int64
#  1   Prix        10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes

# %%
df.isna()
# Out:
#    Supervicie   Prix
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# 5       False  False
# 6       False  False
# 7       False  False
# 8       False  False
# 9       False  False

# %%
df.isna().sum()
# Out:
# Supervicie    0
# Prix          0
# dtype: int64

# %%
df.describe()
# Out:
#        Supervicie          Prix
# count    10.00000     10.000000
# mean    221.30000  17390.000000
# std     153.38481  25705.315058
# min      45.00000    200.000000
# 25%      90.75000   1050.000000
# 50%     175.00000   7750.000000
# 75%     320.00000  14000.000000
# max     450.00000  74000.000000

# %%
df.describe().T
# Out:
#             count     mean           std    min      25%     50%      75%  \
# Supervicie   10.0    221.3    153.384810   45.0    90.75   175.0    320.0
# Prix         10.0  17390.0  25705.315058  200.0  1050.00  7750.0  14000.0
#
#                 max
# Supervicie    450.0
# Prix        74000.0

# %%
plt.xlabel("Superficie")
plt.ylabel("Prix")

plt.scatter(df['Supervicie'], df['Prix'], color='red', marker='*')
