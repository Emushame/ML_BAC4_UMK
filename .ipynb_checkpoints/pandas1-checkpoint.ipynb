# %% [markdown]
# # Cours de Machine learning

# %% [markdown]
# ## Apprentissage supervisé - Regression lineaire

# %% [markdown]
# #### Exercice 1 : Prediction du prix d'une maison en fonction de sa surface

# %% [markdown]
# ### 1. Importation des bibliotheques

# %%
import pandas as pd # pour l'analyse de donneees
import matplotlib.pyplot as plt # pour la visualisation de donnnees
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Chargement des donnees

# %%
df = pd.read_csv("prix_maisons.csv")

# %%
df
# Out:
#    Supervicie  Prix
# 0         200   480
# 1         450   600
# 2         150   420
# 3          80   270
# 4          75   250
# 5         320   560
# 6         320   550
# 7         450   600
# 8         123   350
# 9          45   125

# %%
df.shape
# Out:
# (10, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Supervicie  10 non-null     int64
#  1   Prix        10 non-null     int64
# dtypes: int64(2)
# memory usage: 288.0 bytes

# %%
df.isna()
# Out:
#    Supervicie   Prix
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# 5       False  False
# 6       False  False
# 7       False  False
# 8       False  False
# 9       False  False

# %%
df.isna().sum()
# Out:
# Supervicie    0
# Prix          0
# dtype: int64

# %%
df.describe()
# Out:
#        Supervicie       Prix
# count    10.00000   10.00000
# mean    221.30000  420.50000
# std     153.38481  166.07311
# min      45.00000  125.00000
# 25%      90.75000  290.00000
# 50%     175.00000  450.00000
# 75%     320.00000  557.50000
# max     450.00000  600.00000

# %%
df.describe().T
# Out:
#             count   mean        std    min     25%    50%    75%    max
# Supervicie   10.0  221.3  153.38481   45.0   90.75  175.0  320.0  450.0
# Prix         10.0  420.5  166.07311  125.0  290.00  450.0  557.5  600.0

# %%
plt.xlabel("Superficie")
plt.ylabel("Prix")

plt.scatter(df['Supervicie'], df['Prix'])

# %% [markdown]
# ### 3. Creation du modele de regression lineaire

# %%
lr = linear_model.LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %% [markdown]
# #### 3.1 Entrainer le modele sur les donnees

# %%
y = df[['Prix', 'Supervicie']]
X = df.drop(columns=['Prix'])

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# #### 3.2 Test de la prediction

# %%
prix = lr.predict([[900]])

# %%
print(prix.tolist()[0])
# Out:
# [1102.1373501065686, 900.0000000000003]

# %%
predite = lr.predict(X)

# %%
print("Predicted :", predite)
print("Target :", y)
# Out:
# Predicted : [[399.10781559 200.        ]
#  [650.1897922  450.        ]
#  [348.89142027 150.        ]
#  [278.58846682  80.        ]
#  [273.56682729  75.        ]
#  [519.62716437 320.        ]
#  [519.62716437 320.        ]
#  [650.1897922  450.        ]
#  [321.7745668  123.        ]
#  [243.43699009  45.        ]]
# Target :    Prix  Supervicie
# 0   480         200
# 1   600         450
# 2   420         150
# 3   270          80
# 4   250          75
# 5   560         320
# 6   550         320
# 7   600         450
# 8   350         123
# 9   125          45

# %%
r2_score(y, predite)
# Out:
# 0.930216572013958

# %%
root_mean_squared_error(y,predite)
# Out:
# 29.429421463278334

# %%
mae = mean_absolute_error(y, predite)
print("MAE :",mae)
# Out:
# MAE : 25.09718686080852

# %%
mse = mean_squared_error(y, predite)
mse
# Out:
# 1732.181695326531

# %%
rmse2 = np.sqrt(mse)

# %%
rmse2
# Out:
# np.float64(41.61948696616203)

# %%
rmse = np.sqrt(mae)

# %%
print("RMSE:", rmse)
# Out:
# RMSE: 5.009709259109607

# %%
plt.xlabel("Superficie")
plt.ylabel("Prix")

plt.scatter(df['Supervicie'], df['Prix'], color="red")
plt.plot(df['Supervicie'], lr.predict(df[['Supervicie']]))
